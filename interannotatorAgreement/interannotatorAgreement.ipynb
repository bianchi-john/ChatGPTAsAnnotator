# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../Annotazioni/Annotazioni_controllate.csv')

df
# Out:
#                                         id  \
# 0     18d71db7-f362-46fa-953e-d8353c7f7232
# 1     18d71db7-f362-46fa-953e-d8353c7f7232
# 2     18d71db7-f362-46fa-953e-d8353c7f7232
# 3     3ca70f03-38f3-4a7b-bdd3-f012b22e0c7e
# 4     3ca70f03-38f3-4a7b-bdd3-f012b22e0c7e
# ...                                    ...
# 1058  5b30e244-4aa2-4ad3-b24a-2022c1415df7
# 1059  5b30e244-4aa2-4ad3-b24a-2022c1415df8
# 1060  eab45a62-1d47-4216-a51d-e45ccbcc3810
# 1061  eab45a62-1d47-4216-a51d-e45ccbcc3810
# 1062  eab45a62-1d47-4216-a51d-e45ccbcc3810
#
#                                                   title    label  annotator  \
# 0     Coronavirus| nuove regole: al tavolo al ristor...  Group 2     Manuel
# 1     Coronavirus| nuove regole: al tavolo al ristor...  Group 2  Marinella
# 2     Coronavirus| nuove regole: al tavolo al ristor...  Group 2     Angelo
# 3     Israele: Lapid| ostacoli ma fiducioso su nuovo...  Group 2     Manuel
# ...

# %%
from py_agreement import kappa

# Estrai le annotazioni per ogni annotatore
annotations_manuel = df.loc[df['annotator'] == 'Manuel', 'label']
annotations_marinella = df.loc[df['annotator'] == 'Marinella', 'label']
annotations_angelo = df.loc[df['annotator'] == 'Angelo', 'label']

# Calcola il Cohen's Kappa
kappa_value = kappa(annotations_manuel, annotations_marinella)

# Stampa il valore del Kappa
print(kappa_value)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from py_agreement import kappa
#       3 # Estrai le annotazioni per ogni annotatore
#       4 annotations_manuel = df.loc[df['annotator'] == 'Manuel', 'label']
#
# ModuleNotFoundError: No module named 'py_agreement'
