# %%
import pandas as pd
import numpy as np

df = pd.read_csv('Annotazioni.csv')
df.drop(['url', 'URL(*)', 'Q1.7.1 If the article negatively targets a specific group, please check the types of targeting from the options below', 'Q2.9.2 Exact Date', 'Q2.11 Other media', 'Q2.12 News presented type', 'Q2.13 Visual bias'], axis=1, inplace=True)
df.fillna(0, inplace=True)

df
# Out:
#                                         id  \
# 0     18d71db7-f362-46fa-953e-d8353c7f7232
# 1     18d71db7-f362-46fa-953e-d8353c7f7232
# 2     18d71db7-f362-46fa-953e-d8353c7f7232
# 3     3ca70f03-38f3-4a7b-bdd3-f012b22e0c7e
# 4     3ca70f03-38f3-4a7b-bdd3-f012b22e0c7e
# ...                                    ...
# 1058  5b30e244-4aa2-4ad3-b24a-2022c1415df7
# 1059  5b30e244-4aa2-4ad3-b24a-2022c1415df8
# 1060  eab45a62-1d47-4216-a51d-e45ccbcc3810
# 1061  eab45a62-1d47-4216-a51d-e45ccbcc3810
# 1062  eab45a62-1d47-4216-a51d-e45ccbcc3810
#
#                                                   title    label  annotator  \
# 0     Coronavirus| nuove regole: al tavolo al ristor...  Group 2     Manuel
# 1     Coronavirus| nuove regole: al tavolo al ristor...  Group 2  Marinella
# 2     Coronavirus| nuove regole: al tavolo al ristor...  Group 2     Angelo
# 3     Israele: Lapid| ostacoli ma fiducioso su nuovo...  Group 2     Manuel
# 4     Israele: Lapid| ostacoli ma fiducioso su nuovo...  Group 2  Marinella
# ...                                                 ...      ...        ...
# 1058                Cosa fare dei documenti della Stasi  Group 1  Marinella
# 1059                Cosa fare dei documenti della Stasi  Group 1     Angelo
# 1060  Strani dolori allo stomaco, dopo 6 mesi muore ...  Group 1     Manuel
# 1061  Strani dolori allo stomaco, dopo 6 mesi muore ...  Group 1  Marinella
# 1062  Strani dolori allo stomaco, dopo 6 mesi muore ...  Group 1     Angelo
#
#       Q.1.1 Type of news  Q.1.2 Accuracy Q.1.3 Headline Q1.3.1 Quotation  \
# 0                    1.0             2.0              3                0
# 1                    0.0             0.0              0                0
# 2                    1.0             3.0            1;3                1
# 3                    1.0             4.0            1;3                0
# 4                    1.0             4.0            1;3                -
# ...                  ...             ...            ...              ...
# 1058                 3.0             3.0            1;8                -
# 1059                 3.0             3.0           1;9;                0
# 1060                 0.0             0.0              0                0
# 1061                 1.0             4.0            1;9                -
# 1062                 5.0             4.0           1;9;                0
#
#      Q.1.4 Fact-based lead  Q.1.5 Bias  Q.1.6 Sensational language  \
# 0                        2         4.0                         4.0
# 1                        0         0.0                         0.0
# 2                        1         4.0                         4.0
# 3                        2         4.0                         4.0
# 4                        1         4.0                         4.0
# ...                    ...         ...                         ...
# 1058                     1         4.0                         4.0
# 1059                     2         4.0                         4.0
# 1060                     0         0.0                         0.0
# 1061                     1         4.0                         3.0
# 1062                     2         4.0                         3.0
#
#      Q1.7 Negative target Q2.8 Attribution Q2.9.1 Date Q2.10 event 30 days
# 0                       1                1           2                   2
# 1                       0                0           0                   0
# 2                       1                1           2                   2
# 3                       1                3           2                   2
# 4                       2                3           2                   2
# ...                   ...              ...         ...                 ...
# 1058                    1                1           2                   2
# 1059                    1                1           2                   2
# 1060                    0                0           0                   0
# 1061                    1                3           2                   2
# 1062                    1                3           2                   2
#
# [1063 rows x 15 columns]

# %%
# Pulizie generali

df = df.applymap(lambda x: x.rstrip(';') if isinstance(x, str) else x)
# Out:
# /tmp/ipykernel_16136/1618772241.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.rstrip(';') if isinstance(x, str) else x)

# %%
df
# Out:
#                                         id  \
# 0     18d71db7-f362-46fa-953e-d8353c7f7232
# 1     18d71db7-f362-46fa-953e-d8353c7f7232
# 2     18d71db7-f362-46fa-953e-d8353c7f7232
# 3     3ca70f03-38f3-4a7b-bdd3-f012b22e0c7e
# 4     3ca70f03-38f3-4a7b-bdd3-f012b22e0c7e
# ...                                    ...
# 1058  5b30e244-4aa2-4ad3-b24a-2022c1415df7
# 1059  5b30e244-4aa2-4ad3-b24a-2022c1415df8
# 1060  eab45a62-1d47-4216-a51d-e45ccbcc3810
# 1061  eab45a62-1d47-4216-a51d-e45ccbcc3810
# 1062  eab45a62-1d47-4216-a51d-e45ccbcc3810
#
#                                                   title    label  annotator  \
# 0     Coronavirus| nuove regole: al tavolo al ristor...  Group 2     Manuel
# 1     Coronavirus| nuove regole: al tavolo al ristor...  Group 2  Marinella
# 2     Coronavirus| nuove regole: al tavolo al ristor...  Group 2     Angelo
# 3     Israele: Lapid| ostacoli ma fiducioso su nuovo...  Group 2     Manuel
# 4     Israele: Lapid| ostacoli ma fiducioso su nuovo...  Group 2  Marinella
# ...                                                 ...      ...        ...
# 1058                Cosa fare dei documenti della Stasi  Group 1  Marinella
# 1059                Cosa fare dei documenti della Stasi  Group 1     Angelo
# 1060  Strani dolori allo stomaco, dopo 6 mesi muore ...  Group 1     Manuel
# 1061  Strani dolori allo stomaco, dopo 6 mesi muore ...  Group 1  Marinella
# 1062  Strani dolori allo stomaco, dopo 6 mesi muore ...  Group 1     Angelo
#
#       Q.1.1 Type of news  Q.1.2 Accuracy Q.1.3 Headline Q1.3.1 Quotation  \
# 0                    1.0             2.0              3                0
# 1                    0.0             0.0              0                0
# 2                    1.0             3.0            1;3                1
# 3                    1.0             4.0            1;3                0
# 4                    1.0             4.0            1;3                -
# ...                  ...             ...            ...              ...
# 1058                 3.0             3.0            1;8                -
# 1059                 3.0             3.0            1;9                0
# 1060                 0.0             0.0              0                0
# 1061                 1.0             4.0            1;9                -
# 1062                 5.0             4.0            1;9                0
#
#      Q.1.4 Fact-based lead  Q.1.5 Bias  Q.1.6 Sensational language  \
# 0                        2         4.0                         4.0
# 1                        0         0.0                         0.0
# 2                        1         4.0                         4.0
# 3                        2         4.0                         4.0
# 4                        1         4.0                         4.0
# ...                    ...         ...                         ...
# 1058                     1         4.0                         4.0
# 1059                     2         4.0                         4.0
# 1060                     0         0.0                         0.0
# 1061                     1         4.0                         3.0
# 1062                     2         4.0                         3.0
#
#      Q1.7 Negative target Q2.8 Attribution Q2.9.1 Date Q2.10 event 30 days
# 0                       1                1           2                   2
# 1                       0                0           0                   0
# 2                       1                1           2                   2
# 3                       1                3           2                   2
# 4                       2                3           2                   2
# ...                   ...              ...         ...                 ...
# 1058                    1                1           2                   2
# 1059                    1                1           2                   2
# 1060                    0                0           0                   0
# 1061                    1                3           2                   2
# 1062                    1                3           2                   2
#
# [1063 rows x 15 columns]

# %%
def Q1_1(df, column):
    df[column] = df[column].astype(str)
    df[column] = df[column].str.replace('.0', '')
    valid_values = ['1', '2', '3', '4', '5', '0']
    df[column] = df[column].apply(lambda x: x if x in valid_values else '0')

def Q1_2(df, column):
    df[column] = df[column].astype(str)
    df[column] = df[column].str.replace('.0', '')
    df[column] = df[column].str.replace('nan', '')
    valid_values = ['1', '2', '3', '4', '0']
    df[column] = df[column].apply(lambda x: x if x in valid_values else '0')

def Q1_3(df, column):
    df[column] = df[column].astype(str)
    df[column] = df[column].apply(lambda x: '' if not x.replace(';', '').isdigit() else x)

def Q1_31(df, column):
    df[column] = df[column].astype(str)
    valid_values = ['1', '2', '0']
    df[column] = df[column].apply(lambda x: x if x in valid_values else '0')

def Q1_4(df, column):
    df[column] = df[column].astype(str)
    valid_values = ['1', '2', '0']
    df[column] = df[column].apply(lambda x: x if x in valid_values else '0')

def Q1_5(df, column):
    df[column] = df[column].astype(str)
    df[column] = df[column].str.replace('.0', '')
    valid_values = ['1', '2', '3', '4', '0']
    df[column] = df[column].apply(lambda x: x if x in valid_values else '0')

def Q1_6(df, column):
    df[column] = df[column].astype(str)
    df[column] = df[column].str.replace('.0', '')
    valid_values = ['1', '2', '3', '4', '0']
    df[column] = df[column].apply(lambda x: x if x in valid_values else '0')

def Q1_7(df, column):
    df[column] = df[column].astype(str)
    valid_values = ['1', '2', '0']
    df[column] = df[column].apply(lambda x: x if x in valid_values else '0')

def Q2_8(df, column):
    df[column] = df[column].astype(str)
    valid_values = ['1', '2', '3', '0']
    df[column] = df[column].apply(lambda x: x if x in valid_values else '0')

def Q2_91(df, column):
    df[column] = df[column].astype(str)
    valid_values = ['1', '2', '0']
    df[column] = df[column].apply(lambda x: x if x in valid_values else '0')

def Q2_10(df, column):
    df[column] = df[column].astype(str)
    valid_values = ['1', '2', '0']
    df[column] = df[column].apply(lambda x: x if x in valid_values else '0')

Q1_1(df, 'Q.1.1 Type of news')

Q1_2(df, 'Q.1.2 Accuracy')

Q1_3(df, 'Q.1.3 Headline')

Q1_31(df, 'Q1.3.1 Quotation')

Q1_4(df, 'Q.1.4 Fact-based lead')

Q1_5(df, 'Q.1.5 Bias')

Q1_6(df, 'Q.1.6 Sensational language')

Q1_7(df, 'Q1.7 Negative target')

Q2_8(df, 'Q2.8 Attribution')

Q2_91(df, 'Q2.9.1 Date')

Q2_10(df, 'Q2.10 event 30 days')

# %%
df
# Out:
#                                         id  \
# 0     18d71db7-f362-46fa-953e-d8353c7f7232
# 1     18d71db7-f362-46fa-953e-d8353c7f7232
# 2     18d71db7-f362-46fa-953e-d8353c7f7232
# 3     3ca70f03-38f3-4a7b-bdd3-f012b22e0c7e
# 4     3ca70f03-38f3-4a7b-bdd3-f012b22e0c7e
# ...                                    ...
# 1058  5b30e244-4aa2-4ad3-b24a-2022c1415df7
# 1059  5b30e244-4aa2-4ad3-b24a-2022c1415df8
# 1060  eab45a62-1d47-4216-a51d-e45ccbcc3810
# 1061  eab45a62-1d47-4216-a51d-e45ccbcc3810
# 1062  eab45a62-1d47-4216-a51d-e45ccbcc3810
#
#                                                   title    label  annotator  \
# 0     Coronavirus| nuove regole: al tavolo al ristor...  Group 2     Manuel
# 1     Coronavirus| nuove regole: al tavolo al ristor...  Group 2  Marinella
# 2     Coronavirus| nuove regole: al tavolo al ristor...  Group 2     Angelo
# 3     Israele: Lapid| ostacoli ma fiducioso su nuovo...  Group 2     Manuel
# 4     Israele: Lapid| ostacoli ma fiducioso su nuovo...  Group 2  Marinella
# ...                                                 ...      ...        ...
# 1058                Cosa fare dei documenti della Stasi  Group 1  Marinella
# 1059                Cosa fare dei documenti della Stasi  Group 1     Angelo
# 1060  Strani dolori allo stomaco, dopo 6 mesi muore ...  Group 1     Manuel
# 1061  Strani dolori allo stomaco, dopo 6 mesi muore ...  Group 1  Marinella
# 1062  Strani dolori allo stomaco, dopo 6 mesi muore ...  Group 1     Angelo
#
#      Q.1.1 Type of news Q.1.2 Accuracy Q.1.3 Headline Q1.3.1 Quotation  \
# 0                     1              2              3                0
# 1                     0              0              0                0
# 2                     1              3            1;3                1
# 3                     1              4            1;3                0
# 4                     1              4            1;3                0
# ...                 ...            ...            ...              ...
# 1058                  3              3            1;8                0
# 1059                  3              3            1;9                0
# 1060                  0              0              0                0
# 1061                  1              4            1;9                0
# 1062                  5              4            1;9                0
#
#      Q.1.4 Fact-based lead Q.1.5 Bias Q.1.6 Sensational language  \
# 0                        2          4                          4
# 1                        0          0                          0
# 2                        1          4                          4
# 3                        2          4                          4
# 4                        1          4                          4
# ...                    ...        ...                        ...
# 1058                     1          4                          4
# 1059                     2          4                          4
# 1060                     0          0                          0
# 1061                     1          4                          3
# 1062                     2          4                          3
#
#      Q1.7 Negative target Q2.8 Attribution Q2.9.1 Date Q2.10 event 30 days
# 0                       1                1           2                   2
# 1                       0                0           0                   0
# 2                       1                1           2                   2
# 3                       1                3           2                   2
# 4                       2                3           2                   2
# ...                   ...              ...         ...                 ...
# 1058                    1                1           2                   2
# 1059                    1                1           2                   2
# 1060                    0                0           0                   0
# 1061                    1                3           2                   2
# 1062                    1                3           2                   2
#
# [1063 rows x 15 columns]

# %%
# CASTO I TIPI E PULISCO

# Sostituisci tutte le stringhe vuote con 0 in tutto il dataframe
df.replace(r'^\s*$', '0', regex=True, inplace=True)

# Columns to convert to integers
columns_to_convert = ['Q.1.1 Type of news', 'Q.1.2 Accuracy', 'Q1.3.1 Quotation', 'Q.1.4 Fact-based lead', 'Q.1.5 Bias', 'Q.1.6 Sensational language', 'Q1.7 Negative target', 'Q2.8 Attribution', 'Q2.9.1 Date', 'Q2.10 event 30 days']

for col in columns_to_convert:
    df[col] = df[col].fillna(0).astype(int)

df['Q.1.3 Headline'] = df['Q.1.3 Headline'].str.split(';')

# Sostituire i NaN con 0 nella colonna 'Q.1.3 Headline'
df['Q.1.3 Headline'].fillna(0, inplace=True)


df = df.query('`Q.1.1 Type of news` != 0 & `Q.1.2 Accuracy` != 0')


df
# Out:
# /tmp/ipykernel_16136/2966802505.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Q.1.3 Headline'].fillna(0, inplace=True)
#                                         id  \
# 0     18d71db7-f362-46fa-953e-d8353c7f7232
# 2     18d71db7-f362-46fa-953e-d8353c7f7232
# 3     3ca70f03-38f3-4a7b-bdd3-f012b22e0c7e
# 4     3ca70f03-38f3-4a7b-bdd3-f012b22e0c7e
# 6     34b92f4c-32db-454c-a369-ca2032443f6c
# ...                                    ...
# 1056  ec3a0585-9da6-4732-bf58-c6e659d8e58e
# 1058  5b30e244-4aa2-4ad3-b24a-2022c1415df7
# 1059  5b30e244-4aa2-4ad3-b24a-2022c1415df8
# 1061  eab45a62-1d47-4216-a51d-e45ccbcc3810
# 1062  eab45a62-1d47-4216-a51d-e45ccbcc3810
#
#                                                   title    label  annotator  \
# 0     Coronavirus| nuove regole: al tavolo al ristor...  Group 2     Manuel
# 2     Coronavirus| nuove regole: al tavolo al ristor...  Group 2     Angelo
# 3     Israele: Lapid| ostacoli ma fiducioso su nuovo...  Group 2     Manuel
# 4     Israele: Lapid| ostacoli ma fiducioso su nuovo...  Group 2  Marinella
# 6     Le borsette fatte a 3 euro l'ora vendute a 820...  Group 1     Manuel
# ...                                                 ...      ...        ...
# 1056         La grande ondata di caldo nel Nord America  Group 1     Angelo
# 1058                Cosa fare dei documenti della Stasi  Group 1  Marinella
# 1059                Cosa fare dei documenti della Stasi  Group 1     Angelo
# 1061  Strani dolori allo stomaco, dopo 6 mesi muore ...  Group 1  Marinella
# 1062  Strani dolori allo stomaco, dopo 6 mesi muore ...  Group 1     Angelo
#
#       Q.1.1 Type of news  Q.1.2 Accuracy Q.1.3 Headline  Q1.3.1 Quotation  \
# 0                      1               2            [3]                 0
# 2                      1               3         [1, 3]                 1
# 3                      1               4         [1, 3]                 0
# 4                      1               4         [1, 3]                 0
# 6                      2               3            [3]                 0
# ...                  ...             ...            ...               ...
# 1056                   1               3         [1, 9]                 1
# 1058                   3               3         [1, 8]                 0
# 1059                   3               3         [1, 9]                 0
# 1061                   1               4         [1, 9]                 0
# 1062                   5               4         [1, 9]                 0
#
#       Q.1.4 Fact-based lead  Q.1.5 Bias  Q.1.6 Sensational language  \
# 0                         2           4                           4
# 2                         1           4                           4
# 3                         2           4                           4
# 4                         1           4                           4
# 6                         1           3                           2
# ...                     ...         ...                         ...
# 1056                      2           3                           4
# 1058                      1           4                           4
# 1059                      2           4                           4
# 1061                      1           4                           3
# 1062                      2           4                           3
#
#       Q1.7 Negative target  Q2.8 Attribution  Q2.9.1 Date  Q2.10 event 30 days
# 0                        1                 1            2                    2
# 2                        1                 1            2                    2
# 3                        1                 3            2                    2
# 4                        2                 3            2                    2
# 6                        2                 3            1                    1
# ...                    ...               ...          ...                  ...
# 1056                     1                 1            2                    2
# 1058                     1                 1            2                    2
# 1059                     1                 1            2                    2
# 1061                     1                 3            2                    2
# 1062                     1                 3            2                    2
#
# [671 rows x 15 columns]

# %%
df.dtypes
# Out:
# id                            object
# title                         object
# label                         object
# annotator                     object
# Q.1.1 Type of news             int64
# Q.1.2 Accuracy                 int64
# Q.1.3 Headline                object
# Q1.3.1 Quotation               int64
# Q.1.4 Fact-based lead          int64
# Q.1.5 Bias                     int64
# Q.1.6 Sensational language     int64
# Q1.7 Negative target           int64
# Q2.8 Attribution               int64
# Q2.9.1 Date                    int64
# Q2.10 event 30 days            int64
# dtype: object

# %%
df.to_csv('Annotazioni_controllate.csv', encoding='utf-8', index=False)
