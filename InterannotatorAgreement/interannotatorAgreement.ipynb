# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import cohen_kappa_score

le = LabelEncoder()


df = pd.read_csv('../Annotations/Annotations_checked.csv')

# Faccio label encoding di Headline

df['Q1.3'] = le.fit_transform(df['Q1.3'])

df['Q1.7.1'] = le.fit_transform(df['Q1.7.1'])
df
# Out:
#                                        id  \
# 0    18d71db7-f362-46fa-953e-d8353c7f7232
# 1    18d71db7-f362-46fa-953e-d8353c7f7232
# 2    3ca70f03-38f3-4a7b-bdd3-f012b22e0c7e
# 3    3ca70f03-38f3-4a7b-bdd3-f012b22e0c7e
# 4    34b92f4c-32db-454c-a369-ca2032443f6c
# ..                                    ...
# 666  ec3a0585-9da6-4732-bf58-c6e659d8e58e
# 667  5b30e244-4aa2-4ad3-b24a-2022c1415df7
# 668  5b30e244-4aa2-4ad3-b24a-2022c1415df8
# 669  eab45a62-1d47-4216-a51d-e45ccbcc3810
# 670  eab45a62-1d47-4216-a51d-e45ccbcc3810
#
#                                                  title    label  annotator  \
# 0    Coronavirus| nuove regole: al tavolo al ristor...  Group 2     Manuel
# 1    Coronavirus| nuove regole: al tavolo al ristor...  Group 2     Angelo
# 2    Israele: Lapid| ostacoli ma fiducioso su nuovo...  Group 2     Manuel
# 3    Israele: Lapid| ostacoli ma fiducioso su nuovo...  Group 2  Marinella
# 4    Le borsette fatte a 3 euro l'ora vendute a 820...  Group 1     Manuel
# ...

# %%
from sklearn.metrics import cohen_kappa_score
from datetime import datetime

# Per ciascun articolo condiviso, calcola il coefficiente Kappa di Cohen
def getKappa (annotator_1, annotator_2):
# Inizializza una lista per memorizzare i coefficienti Kappa di Cohen
    kappa_scores = []

    articles = set(df[df['annotator'] == annotator_1]['id']).intersection(
    set(df[df['annotator'] == annotator_2]['id']))
    for article_id in articles:
        annotator1 = df[(df['id'] == article_id) & (df['annotator'] == annotator_1)][['Q1.1', 'Q1.2', 'Q1.3', 'Q1.3.1', 'Q1.4', 'Q1.5', 'Q1.6', 'Q1.7','Q1.7.1', 'Q2.8', 'Q2.9.1', 'Q2.9.2', 'Q2.10']]
        annotator2 = df[(df['id'] == article_id) & (df['annotator'] == annotator_2)][['Q1.1', 'Q1.2', 'Q1.3', 'Q1.3.1', 'Q1.4', 'Q1.5', 'Q1.6', 'Q1.7','Q1.7.1', 'Q2.8', 'Q2.9.1', 'Q2.9.2', 'Q2.10']]

        annotator1['Q2.9.2'] = pd.to_datetime(annotator1['Q2.9.2'])
        annotator2['Q2.9.2'] = pd.to_datetime(annotator2['Q2.9.2'])

        annotator1['Q2.9.2'] = annotator1['Q2.9.2'].astype('int64')
        annotator2['Q2.9.2'] = annotator2['Q2.9.2'].astype('int64')

        # Converti i valori in numeri interi o float
        annotator1 = annotator1.astype(float)
        annotator2 = annotator2.astype(float)
        
        # Calcola il coefficiente Kappa di Cohen per ciascuna coppia di annotatori
        k = cohen_kappa_score(annotator1.values.flatten(), annotator2.values.flatten())
        kappa_scores.append(k)
    mean_kappa = sum(kappa_scores) / len(kappa_scores)

    print ('Il K tra ' + str(annotator_1) +' e ' + str(annotator_2) +' è  di: '  + str(mean_kappa))
    return mean_kappa

k_manuel_angelo = getKappa('Manuel', 'Angelo')
k_manuel_marinella = getKappa('Manuel', 'Marinella')
k_angelo_marinella = getKappa('Angelo', 'Marinella')
# Out:
# ------------------
# 465    1.625616e+18
# Name: Q2.9.2, dtype: float64
# 466    1.625616e+18
# Name: Q2.9.2, dtype: float64
# ------------------
# ------------------
# 598    1.625789e+18
# Name: Q2.9.2, dtype: float64
# 599   -9.223372e+18
# Name: Q2.9.2, dtype: float64
# ------------------
# ------------------
# 394   -9.223372e+18
# Name: Q2.9.2, dtype: float64
# 395   -9.223372e+18
# Name: Q2.9.2, dtype: float64
# ------------------
# ------------------
# 515   -9.223372e+18
# Name: Q2.9.2, dtype: float64
# 516    1.625098e+18
# Name: Q2.9.2, dtype: float64
# ------------------
# ------------------
# 441    1.620864e+18
# Name: Q2.9.2, dtype: float64
# 442   -9.223372e+18
# Name: Q2.9.2, dtype: float64
# ------------------
# ------------------
# 570    1.625616e+18
# Name: Q2.9.2, dtype: float64
# 571    1.625616e+18
# Name: Q2.9.2, dtype: float64
# ------------------
# ------------------
# 30    1.620518e+18
# Name: Q2.9.2, dtype: float64
# 31    1.620518e+18
# ...

# %% [markdown]
# https://it.wikipedia.org/wiki/Kappa_di_Cohen#:~:text=se%20k%20assume%20valori%20compresi,1%2C%20la%20concordanza%20%C3%A8%20ottima
#
# se k assume valori compresi tra 0-0,4, allora la concordanza è scarsa; se k assume valori compresi tra 0,4-0,6, allora la concordanza è discreta; se k assume valori compresi tra 0,6-0,8, la concordanza è buona; se k assume valori compresi tra 0,8-1, la concordanza è ottima.
