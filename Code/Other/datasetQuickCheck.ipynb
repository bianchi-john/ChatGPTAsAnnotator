# %%
import pandas as pd

df = pd.read_csv('../merged_checked.csv')

df
# Out:
#                                         id  \
# 0     18d71db7-f362-46fa-953e-d8353c7f7232
# 1     18d71db7-f362-46fa-953e-d8353c7f7232
# 2     3ca70f03-38f3-4a7b-bdd3-f012b22e0c7e
# 3     3ca70f03-38f3-4a7b-bdd3-f012b22e0c7e
# 4     34b92f4c-32db-454c-a369-ca2032443f6c
# ...                                    ...
# 1010  95357073-ff48-47ab-a0ad-62324150033a
# 1011  d30b11b6-a665-438c-8ee2-12ea175daeb5
# 1012  abe99528-6405-4ebb-9b2f-2e76fb08ac53
# 1013  8633735e-f183-4d8e-a1e7-9d49b1a2a7b4
# 1014  23bae5d9-64ee-46b3-b479-ebd24f5f4a98
#
#                                                   title    label  \
# 0     Coronavirus| nuove regole: al tavolo al ristor...  Group 2
# 1     Coronavirus| nuove regole: al tavolo al ristor...  Group 2
# 2     Israele: Lapid| ostacoli ma fiducioso su nuovo...  Group 2
# 3     Israele: Lapid| ostacoli ma fiducioso su nuovo...  Group 2
# 4     Le borsette fatte a 3 euro l'ora vendute a 820...  Group 1
# ...                                                 ...      ...
# 1010  L’imprenditore che produce monoclonali a Latin...  Group 1
# 1011  I nuovi colori da lunedì 17 maggio, l’ordinanz...  Group 1
# 1012          Anche le Carresi inseguono la Zona Bianca  Group 2
# 1013          Le stoccate di Draghi per infilzare Conte  Group 1
# 1014  Natalità. Assegni generosi, congedi e servizi....  Group 1
#
#                 annotator  Q1.1  Q1.2 Q1.3  Q1.3.1  Q1.4  Q1.5  Q1.6  Q1.7  \
# 0                  Manuel     1     2    3      -1     2     4     4     1
# 1                  Angelo     1     3  1;3       1     1     4     4     1
# 2                  Manuel     1     4  1;3      -1     2     4     4     1
# 3               Marinella     1     4  1;3      -1     1     4     4     2
# 4                  Manuel     2     3    3      -1     1     3     2     2
# ...                   ...   ...   ...  ...     ...   ...   ...   ...   ...
# 1010  ChatGPT4AsAnnotator     3     4    1       2     2     3     3     1
# 1011  ChatGPT4AsAnnotator     1     4    1       2     2     4     3     1
# 1012  ChatGPT4AsAnnotator     3     4    1       2     2     4     3     1
# 1013  ChatGPT4AsAnnotator     2     4    1       2     2     2     2     2
# 1014  ChatGPT4AsAnnotator     3     4    1       2     2     4     3     1
#
#      Q1.7.1                         Q1.7.1.2  Q2.8  Q2.9.1      Q2.9.2  Q2.10
# 0        -1                               -1     1       2  2021-05-31      2
# 1        -1                               -1     1       2  2021-05-31      2
# 2        -1                               -1     3       2  2021-05-31      2
# 3        11                               -1     3       2  2021-05-31      2
# 4        11  Fashion craft industries system     3       1         NaN      1
# ...     ...                              ...   ...     ...         ...    ...
# 1010     -1                               -1     3       2  2021-02-01      2
# 1011    NaN                               -1     3       2  2021-05-17      2
# 1012     -1                               -1     3       2         NaN      1
# 1013     11                   Giuseppe Conte     3       2         NaN      1
# 1014     -1                               -1     3       2         NaN      1
#
# [1015 rows x 18 columns]

# %%
df.loc[df['Q1.3.1'] == 2]
# Out:
#                                         id  \
# 10    1e96c067-412e-4a93-9dc3-2838ef233942
# 11    1e96c067-412e-4a93-9dc3-2838ef233942
# 12    0c834cb0-392a-4a5e-948f-237a2c8bef31
# 13    0c834cb0-392a-4a5e-948f-237a2c8bef31
# 17    1ad53ecb-251d-4b3f-bbb1-22a38e4c398a
# ...                                    ...
# 1010  95357073-ff48-47ab-a0ad-62324150033a
# 1011  d30b11b6-a665-438c-8ee2-12ea175daeb5
# 1012  abe99528-6405-4ebb-9b2f-2e76fb08ac53
# 1013  8633735e-f183-4d8e-a1e7-9d49b1a2a7b4
# 1014  23bae5d9-64ee-46b3-b479-ebd24f5f4a98
#
#                                                   title    label  \
# 10    Caso Ciro Grillo| i video e quella telefonata ...  Group 1
# 11    Caso Ciro Grillo| i video e quella telefonata ...  Group 1
# 12    La madre della neonata salvata in mare: «Chied...  Group 2
# 13    La madre della neonata salvata in mare: «Chied...  Group 2
# 17    Istituto Mattei| i vincitori del concorso lett...  Group 1
# ...                                                 ...      ...
# 1010  L’imprenditore che produce monoclonali a Latin...  Group 1
# 1011  I nuovi colori da lunedì 17 maggio, l’ordinanz...  Group 1
# 1012          Anche le Carresi inseguono la Zona Bianca  Group 2
# 1013          Le stoccate di Draghi per infilzare Conte  Group 1
# 1014  Natalità. Assegni generosi, congedi e servizi....  Group 1
#
#                 annotator  Q1.1  Q1.2   Q1.3  Q1.3.1  Q1.4  Q1.5  Q1.6  Q1.7  \
# 10                 Manuel     1     3    1;4       2     2     4     4     1
# 11              Marinella     1     4  1;3;4       2     2     4     3     1
# 12                 Manuel     2     3    4;9       2     2     3     2     2
# 13                 Angelo     3     3    3;4       2     1     3     2     2
# 17              Marinella     1     4    1;4       2     1     4     4     1
# ...                   ...   ...   ...    ...     ...   ...   ...   ...   ...
# 1010  ChatGPT4AsAnnotator     3     4      1       2     2     3     3     1
# 1011  ChatGPT4AsAnnotator     1     4      1       2     2     4     3     1
# 1012  ChatGPT4AsAnnotator     3     4      1       2     2     4     3     1
# 1013  ChatGPT4AsAnnotator     2     4      1       2     2     2     2     2
# 1014  ChatGPT4AsAnnotator     3     4      1       2     2     4     3     1
#
#      Q1.7.1               Q1.7.1.2  Q2.8  Q2.9.1      Q2.9.2  Q2.10
# 10       -1                     -1     1       1         NaN      1
# 11       -1                     -1     3       2  2019-08-09      1
# 12       11                     -1     3       2  2021-05-20      2
# 13       11  Government of Morocco     3       2  2021-05-20      2
# 17       -1                     -1     1       2  2021-05-13      2
# ...     ...                    ...   ...     ...         ...    ...
# 1010     -1                     -1     3       2  2021-02-01      2
# 1011    NaN                     -1     3       2  2021-05-17      2
# 1012     -1                     -1     3       2         NaN      1
# 1013     11         Giuseppe Conte     3       2         NaN      1
# 1014     -1                     -1     3       2         NaN      1
#
# [366 rows x 18 columns]

# %%
an_manuel = df.loc[df["annotator"]=="Manuel"]
an_chatgpt = df.loc[df["annotator"]=="ChatGPT4AsAnnotator"]

id_diff_resp = pd.merge(
    an_manuel,
    an_chatgpt,
    how="left",
    left_on="id",
    right_on="id",
    validate="one_to_one"
)

# %%
id_diff_resp = id_diff_resp.loc[id_diff_resp["annotator_y"].notnull()]

# %%
id_diff_resp
# Out:
#                                        id  \
# 0    18d71db7-f362-46fa-953e-d8353c7f7232
# 2    34b92f4c-32db-454c-a369-ca2032443f6c
# 3    1e96c067-412e-4a93-9dc3-2838ef233942
# 4    0c834cb0-392a-4a5e-948f-237a2c8bef31
# 5    184a4635-a693-4ccd-af1a-143455c391e1
# ..                                    ...
# 232  6ede1205-d74f-4bb1-8c37-15fc5b4738ac
# 233  0dc73a1c-4c03-4b2f-8344-f3c898900c01
# 234  cb932977-03e8-46fd-bd91-34e28dba01bd
# 236  2e46bc4c-a4bb-4d18-ab2b-94dc738db629
# 237  3dba1506-79ad-4986-8e89-8af3ace87096
#
#                                                title_x  label_x annotator_x  \
# 0    Coronavirus| nuove regole: al tavolo al ristor...  Group 2      Manuel
# 2    Le borsette fatte a 3 euro l'ora vendute a 820...  Group 1      Manuel
# 3    Caso Ciro Grillo| i video e quella telefonata ...  Group 1      Manuel
# 4    La madre della neonata salvata in mare: «Chied...  Group 2      Manuel
# 5    Finanziaria: almeno 150 milioni nella variazio...  Group 2      Manuel
# ..                                                 ...      ...         ...
# 232     Il degrado di Milano oltre i limiti di guardia  Group 1      Manuel
# 233                                      Habemus Papam  Group 1      Manuel
# 234  Il Cts cambia idea suAstrazeneca.Ormai è chiar...  Group 2      Manuel
# 236      I chiusuristi tifano per l’emergenza continua  Group 2      Manuel
# 237  Enrichetto si schianta sulla legge Lgbt e l’al...  Group 1      Manuel
#
#      Q1.1_x  Q1.2_x Q1.3_x  Q1.3.1_x  Q1.4_x  Q1.5_x  ...  Q1.4_y  Q1.5_y  \
# 0         1       2      3        -1       2       4  ...     2.0     4.0
# 2         2       3      3        -1       1       3  ...     2.0     3.0
# 3         1       3    1;4         2       2       4  ...     2.0     3.0
# 4         2       3    4;9         2       2       3  ...     2.0     4.0
# 5         1       4      3        -1       2       4  ...     2.0     4.0
# ..      ...     ...    ...       ...     ...     ...  ...     ...     ...
# 232       2       3      1        -1       1       2  ...     2.0     2.0
# 233       2       2      9        -1       1       2  ...     2.0     2.0
# 234       2       2    1;3        -1       1       2  ...     2.0     2.0
# 236       3       2      9        -1       1       2  ...     2.0     3.0
# 237       2       3    1;9        -1       1       2  ...     2.0     2.0
#
#     Q1.6_y Q1.7_y  Q1.7.1_y                                        Q1.7.1.2_y  \
# 0      3.0    1.0        -1                                                -1
# 2      2.0    2.0        10             Pelletteria Serena di Poggio a Caiano
# 3      3.0    2.0         9                        Silvia, a 19-year-old girl
# 4      3.0    2.0       4;9                        Immigrants, Race/ethnicity
# 5      3.0    1.0       NaN                                                -1
# ..     ...    ...       ...                                               ...
# 232    2.0    2.0       1;9                          Liberals, Race/ethnicity
# 233    2.0    2.0       3;7                    LGBTQ, Christians/Christianity
# 234    2.0    2.0        11                                   RobertoSperanza
# 236    2.0    2.0       0;1  Francesco Boccia, Matteo Salvini, Giorgia Meloni
# 237    2.0    2.0        11                                      Matteo Renzi
#
#     Q2.8_y  Q2.9.1_y    Q2.9.2_y Q2.10_y
# 0      3.0       2.0         NaN     2.0
# 2      3.0       2.0  2021-05-25     1.0
# 3      3.0       2.0  2019-07-17     1.0
# 4      3.0       2.0         NaN     2.0
# 5      3.0       2.0  2021-05-31     2.0
# ..     ...       ...         ...     ...
# 232    3.0       2.0         NaN     2.0
# 233    1.0       2.0         NaN     1.0
# 234    3.0       2.0         NaN     2.0
# 236    3.0       2.0  2021-07-31     2.0
# 237    3.0       2.0         NaN     1.0
#
# [226 rows x 35 columns]

# %%
id_diff_resp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 226 entries, 0 to 237
# Data columns (total 35 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           226 non-null    object
#  1   title_x      226 non-null    object
#  2   label_x      226 non-null    object
#  3   annotator_x  226 non-null    object
#  4   Q1.1_x       226 non-null    int64
#  5   Q1.2_x       226 non-null    int64
#  6   Q1.3_x       226 non-null    object
#  7   Q1.3.1_x     226 non-null    int64
#  8   Q1.4_x       226 non-null    int64
#  9   Q1.5_x       226 non-null    int64
#  10  Q1.6_x       226 non-null    int64
#  11  Q1.7_x       226 non-null    int64
#  12  Q1.7.1_x     226 non-null    object
#  13  Q1.7.1.2_x   226 non-null    object
#  14  Q2.8_x       226 non-null    int64
#  15  Q2.9.1_x     226 non-null    int64
#  16  Q2.9.2_x     146 non-null    object
#  17  Q2.10_x      226 non-null    int64
#  18  title_y      226 non-null    object
#  19  label_y      226 non-null    object
#  20  annotator_y  226 non-null    object
#  21  Q1.1_y       226 non-null    float64
#  22  Q1.2_y       226 non-null    float64
#  23  Q1.3_y       226 non-null    object
#  24  Q1.3.1_y     226 non-null    float64
#  25  Q1.4_y       226 non-null    float64
#  26  Q1.5_y       226 non-null    float64
#  27  Q1.6_y       226 non-null    float64
#  28  Q1.7_y       226 non-null    float64
#  29  Q1.7.1_y     176 non-null    object
#  30  Q1.7.1.2_y   226 non-null    object
#  31  Q2.8_y       226 non-null    float64
#  32  Q2.9.1_y     226 non-null    float64
#  33  Q2.9.2_y     127 non-null    object
#  34  Q2.10_y      226 non-null    float64
# dtypes: float64(10), int64(10), object(15)
# memory usage: 63.6+ KB

# %%
temp = id_diff_resp.loc[id_diff_resp["Q1.7.1_x"]!=id_diff_resp["Q1.7.1_y"]][["id", "annotator_x", "Q1.7.1_x", "annotator_y", "Q1.7.1_y", "title_x"]]
# temp = id_diff_resp.loc[(id_diff_resp["Q1.2_x"]!=id_diff_resp["Q1.2_y"]) & 
#                         (id_diff_resp["Q1.1_x"]!=id_diff_resp["Q1.1_y"]) & 
#                         (id_diff_resp["Q1.3.1_x"]!=id_diff_resp["Q1.3.1_y"]) &
#                         (id_diff_resp["Q1.4_x"]!=id_diff_resp["Q1.4_y"]) &
#                         (id_diff_resp["Q1.5_x"]!=id_diff_resp["Q1.5_y"]) &
#                         (id_diff_resp["Q1.6_x"]!=id_diff_resp["Q1.6_y"]) &
#                         (id_diff_resp["Q1.7_x"]!=id_diff_resp["Q1.7_y"])
#                         ][["id", "annotator_x", "Q1.2_x", "annotator_y", "Q1.2_y", "title_x"]]

temp.to_csv('export.csv')
